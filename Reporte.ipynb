# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importar cvs
eCRC = pd.read_csv('output/emisor_CRC.csv')
eHam = pd.read_csv('output/emisor_Ham.csv')
rCRC = pd.read_csv('output/receptor_CRC.csv')
rHam = pd.read_csv('output/receptor_Ham.csv')

# %%
eCRC
# Out:
#       id                trama_og  \
# 0      0           '00001111011'
# 1      1       '001111100111000'
# 2      2        '10001101101000'
# 3      3       '101010010101100'
# 4      4         '1000111111101'
# ..   ...                     ...
# 495  495       '000010011011111'
# 496  496    '110110110011011010'
# 497  497  '11110011111110111100'
# 498  498           '00010101010'
# 499  499          '000001010111'
#
#                                               codified  \
# 0         '000011110111110001001101000010011001001100'
# 1     '0011111001110001000001010100101100010001000100'
# 2      '100011011010001101001000011000110001001010100'
# 3     '1010100101011000111010001111010000101111011000'
# 4       '10001111111011110100110000010100010001100010'
# ..                                                 ...
# 495   '0000100110111110111000110011000110111101110000'
# 496  '110110110011011010110100011110101010001000110...
# 497  '111100111111101111000101001111011010001110100...
# ...

# %%
eHam
# Out:
#       id                trama_og  \
# 0      0           '00001111011'
# 1      1       '001111100111000'
# 2      2        '10001101101000'
# 3      3       '101010010101100'
# 4      4         '1000111111101'
# ..   ...                     ...
# 495  495       '000010011011111'
# 496  496    '110110110011011010'
# 497  497  '11110011111110111100'
# 498  498           '00010101010'
# 499  499          '000001010111'
#
#                                               codified  \
# 0                   '101010111110000;1001;00001111011'
# 1         '11000011110011101100;11010;001111100111000'
# 2           '0101001001101101001;01101;10001101101000'
# 3         '01010111010100100101;01110;101010010101100'
# 4             '101001111111100101;10011;1000111111101'
# ..                                                 ...
# 495       '01111110101100100000;01100;000010011011111'
# 496  '00011010101100111011011;00101;110110110011011...
# 497  '0100011011011111111001111;01001;1111001111111...
# ...

# %%
rCRC
# Out:
#       id                                       alg_received  err  \
# 0      0       '000011110111110001001101000010011001001100'  '0'
# 1      1   '0011111001110001000001010100101100010001000100'  '0'
# 2      2   '1000110110100011010010000101000110001001010100'  '1'
# 3      3   '1010100101011000111010001111010000101111011000'  '0'
# 4      4    '100011111110111101001100000010100010001100010'  '1'
# ..   ...                                                ...  ...
# 495  495   '0000100110111110111000110011000110111101110000'  '0'
# 496  496  '110110110011011010101010001111010101000100011...  '1'
# 497  497  '111100111111101111000101001111011010001110100...  '0'
# 498  498       '000101010100011001010101011100110101000100'  '0'
# 499  499      '0000010101111100110100000001111101110010110'  '0'
#
#                                     res
# 0    '00000000000000000000000000000000'
# 1    '00000000000000000000000000000000'
# 2    '00000000000011001010011011111100'
# ...

# %%
rHam
# Out:
#       id                                       alg_received  \
# 0      0                 '101010111110000;1001;00001111011'
# 1      1       '11000011110011101100;11010;001111100111000'
# 2      2         '0101001001101101001;01101;10001101101000'
# 3      3       '01010111010100100101;01110;101010010101100'
# 4      4           '101001111111100101;10011;1000111111101'
# ..   ...                                                ...
# 495  495       '01111110101100100000;01100;000010011011111'
# 496  496  '00011010101100111011011;00101;110110110011011...
# 497  497  '0100011011011111111001111;01001;1111001111111...
# 498  498                 '000110100101000;0010;00010101010'
# 499  499             '01101100101000000;01000;000001010111'
#
#                             bits     reqs                    orig     corr  \
# 0              '101010111110000'   '1001'           '00001111011'   '1000'
# 1         '11000011110011101100'  '11010'       '001111100111000'  '11110'
# ...

# %% [markdown]
# ## CRC-32

# %%
ceros_eCRC = eCRC["w_noise"].value_counts()
ceros_rCRC = rCRC["err"].value_counts()
print("Cantidad de cadenas correcta(0) y modificadas(1) enviadas")
print(ceros_eCRC)
print("Cantidad de cadenas correcta(0) y modificadas(1) recibidas")
print(ceros_rCRC)
# Out:
# Cantidad de cadenas correcta(0) y modificadas(1) enviadas
# '0'    478
# '1'     22
# Name: w_noise, dtype: int64
# Cantidad de cadenas correcta(0) y modificadas(1) recibidas
# '0'    479
# '1'     21
# Name: err, dtype: int64

# %%
# Data for the pie chart
labels = ['correctas', 'modificadas']
sizes = [ceros_eCRC[0], ceros_eCRC[1]]  # Percentages or values for each category

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Add a title
plt.title("Cadenas correctas e incorrectas, CRC")

# Show the pie chart
plt.show()

# %%
ceros_eHAM = eHam["w_noise"].value_counts()
print("Cantidad de cadenas correcta(0) y modificadas(1) enviadas")
print(ceros_eHAM)
# Out:
# Cantidad de cadenas correcta(0) y modificadas(1) enviadas
# '0'    498
# '1'      2
# Name: w_noise, dtype: int64

# %%
switches_general = 0
digitos_general = 0
porPalabra = []

for x in eCRC['id']:
    # for y in eCRC['codified'][x][1:-1]:
    for i in range(len(eCRC['codified'][x])):
        if eCRC['codified'][x] != "'":
            digitos_general += 1
            
            if eCRC['codified'][x][i] != eCRC['modified'][x][i]:
                switches_general += 1
                        
print(switches_general)
print(digitos_general)
# Out:
# 282
# 22998

# %%
# Data for the pie chart
labels = ['switches', 'íntegros']
sizes = [switches_general, digitos_general - switches_general]  # Percentages or values for each category

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Add a title
plt.title("Porcentajes de bits cambiados e íntegros, CRC")

# Show the pie chart
plt.show()

# %% [markdown]
# ## Hamming

# %%
# Buscando si todas las tramas transferidas y corregidas son exáctamente las mismas

cont = 0
for x in range(len(eHam)):
    if eHam.trama_og[x] != rHam.orig[x]:
        cont += 1
        
print("Cantidad de tramas que difieren entre emisor y receptor: ", cont)
# Out:
# Cantidad de tramas que difieren entre emisor y receptor:  0

# %%
# Data for the pie chart
labels = ['difieren', 'Correctos']
sizes = [cont, 500-cont]  # Percentages or values for each category

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Add a title
plt.title("Tramas que difieren entre emisor y receptor, Hamming")

# Show the pie chart
plt.show()

# %%
switches_general = 0
digitos_general = 0
porPalabra = []

for x in eHam['id']:
    # for y in eCRC['codified'][x][1:-1]:
    for i in range(len(eHam['codified'][x])):
        if eHam['codified'][x] != "'" and eHam['codified'][x] != ";":
            digitos_general += 1
            
            if eHam['codified'][x][i] != eHam['modified'][x][i]:
                switches_general += 1
            
                        
print(switches_general)
print(digitos_general)
# Out:
# 23
# 19656

# %%
# Data for the pie chart
labels = ['switches', 'íntegros']
sizes = [switches_general, digitos_general - switches_general]  # Percentages or values for each category

# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Add a title
plt.title("Porcentajes de bits cambiados e íntegros")

# Show the pie chart
plt.show()
